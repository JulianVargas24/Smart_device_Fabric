# %%
import smtplib
from email.mime.text import MIMEText

subject = 'Pipeline Error'
body = 'El proceso de pipeline ha caido en error debido a que no se encuentra la carpeta'
sender = 'vargasjulian.2207@gmail.com'
my_password = 'yfeoebiutrfypkuf'
recipients = [sender]

def send_mail(subject, body, sender, recipients):
    msg = MIMEText(body)
    msg['subject'] = subject
    msg['From'] = sender
    msg['To'] = ', '.join(recipients)

    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
        smtp_server.login(sender, my_password)
        smtp_server.sendmail(sender, recipients, msg.as_string())
    print("Mensaje enviado!")

send_mail(subject, body, sender, recipients)
# Out:
# StatementMeta(, a4502441-f2a6-4dc0-b476-543aff27d568, 3, Finished, Available, Finished)
# Mensaje enviado!
